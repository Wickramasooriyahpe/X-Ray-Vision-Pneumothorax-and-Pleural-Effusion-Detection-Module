# %% [markdown]
# # Load Image Set

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Check the directory structure to ensure the correct path
segmented_base_dir = "/content/drive/MyDrive/FYP/Lung/Segmented Images"

# Path to the directory containing segmented images
segmented_images_dir = os.path.join(segmented_base_dir, "Pneumothorax")
print(f"Using images directory: {segmented_images_dir}")
# Out:
# Using images directory: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax

# %%
# Check the directory structure to ensure the correct path
bone_suppressed_base_dir = "/content/drive/MyDrive/FYP/Lung/Bone Suppressed"

# Path to the directory containing segmented images
bone_suppressed_images_dir = os.path.join(bone_suppressed_base_dir, "Pneumothorax")
print(f"Using images directory: {bone_suppressed_images_dir}")
# Out:
# Using images directory: /content/drive/MyDrive/FYP/Lung/Bone Suppressed/Pneumothorax

# %% [markdown]
# # Pre Process the Images

# %%
def preprocess_image(image_path):
   # Load the image in grayscale
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Step 1: Preprocess the image using GaussianBlur
    blurred = cv2.GaussianBlur(image, (5, 5), 0)

    # Step 2: Thresholding to create a binary image
    _, binary = cv2.threshold(blurred, 60, 255, cv2.THRESH_BINARY_INV)
    return binary

# %% [markdown]
# # Identify Dark Lung Areas

# %%
def detect_combined_homogeneous_area(image_path):
    # Load the image in grayscale
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Step 1: Preprocess the image using GaussianBlur
    blurred = cv2.GaussianBlur(image, (5, 5), 0)

    # Step 2: Thresholding to create a binary image
    _, binary = cv2.threshold(blurred, 60, 255, cv2.THRESH_BINARY_INV)  # Adjusted threshold value

    # Step 3: Morphological operations to clean up the binary image
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
    cleaned = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)

    # Step 4: Find contours in the binary image
    contours, _ = cv2.findContours(cleaned, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Create an output image to draw detected areas
    output_image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)

    # Function to check if a contour area is homogeneous
    def is_homogeneous_area(contour, image):
        mask = np.zeros_like(image)
        cv2.drawContours(mask, [contour], -1, 255, thickness=cv2.FILLED)
        area_intensity = cv2.mean(image, mask=mask)[0]
        area_std_dev = np.std(image[mask == 255])
        return area_std_dev < 200  # Adjust the threshold for homogeneity

    # Function to separate low-contrast and high-contrast areas
    def separate_contrast_areas(contour, image):
        mask = np.zeros_like(image)
        cv2.drawContours(mask, [contour], -1, 255, thickness=cv2.FILLED)
        mean_intensity = cv2.mean(image, mask=mask)[0]
        return mean_intensity < 50  # Adjust the threshold for separating contrast areas

    # Step 5: Filter and identify the homogeneous areas
    detected_areas = []
    for contour in contours:
        if is_homogeneous_area(contour, image) and separate_contrast_areas(contour, image):
            detected_areas.append(contour)

    # Step 6: Create a mask for the detected homogeneous areas
    mask = np.zeros_like(image)
    for contour in detected_areas:
        cv2.drawContours(mask, [contour], -1, 255, thickness=cv2.FILLED)

    # Step 7: Apply dilation followed by erosion to combine nearby areas
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (10, 10))  # Adjust kernel size as needed
    dilated = cv2.dilate(mask, kernel, iterations=2)
    eroded = cv2.erode(dilated, kernel, iterations=2)

    # Step 8: Find the contour of the combined region
    combined_contours, _ = cv2.findContours(eroded, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Draw the combined contour on the output image
    if combined_contours:
        cv2.drawContours(output_image, combined_contours, -1, (0, 255, 255), 2)

    return combined_contours, output_image

# %% [markdown]
# # Identify Visible Plural Line

# %%
def detect_pleural_line(image_path):
    # Load the image in grayscale
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Step 1: Preprocess the image using GaussianBlur
    blurred = cv2.GaussianBlur(image, (5, 5), 0)

    # Step 2: Edge detection using Canny
    edges = cv2.Canny(blurred, 30, 150)  # Adjusted parameters for Canny edge detection

    # Step 3: Line detection using Hough Transform
    lines = cv2.HoughLinesP(edges, 1, np.pi/180, threshold=50, minLineLength=30, maxLineGap=10)

    # Create an output image to draw lines
    output_image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)

    # Function to check if a line is homogeneous
    def is_homogeneous_line(x1, y1, x2, y2, image):
        line_intensity = []
        num_points = max(abs(x2 - x1), abs(y2 - y1))
        for i in range(num_points + 1):
            x = int(x1 + i * (x2 - x1) / num_points)
            y = int(y1 + i * (y2 - y1) / num_points)
            line_intensity.append(image[y, x])

        if len(line_intensity) < 2:
            return False

        # Calculate the standard deviation of the intensities along the line
        std_dev = np.std(line_intensity)
        # Check if the line intensity is relatively consistent (low standard deviation)
        return std_dev < 20

    # Function to check if a line separates dark and light areas
    def separate_dark_light_areas(x1, y1, x2, y2, image):
        midpoint_x = (x1 + x2) // 2
        midpoint_y = (y1 + y2) // 2
        left_intensity = np.mean(image[max(0, midpoint_y - 5):midpoint_y + 5, max(0, midpoint_x - 20):midpoint_x])
        right_intensity = np.mean(image[max(0, midpoint_y - 5):midpoint_y + 5, midpoint_x:min(image.shape[1], midpoint_x + 20)])
        return abs(left_intensity - right_intensity) > 50

    # Step 4: Filter and identify the pleural line
    detected_lines = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            if is_homogeneous_line(x1, y1, x2, y2, image) and separate_dark_light_areas(x1, y1, x2, y2, image):
                # Draw the detected pleural line on the output image
                cv2.line(output_image, (x1, y1), (x2, y2), (0, 255, 0), 2)
                detected_lines.append((x1, y1, x2, y2))

    return detected_lines

# %% [markdown]
# # Predict Pneumothorax

# %%
def predict_pneumothorax(segmented_image_path):
    combined_contours, output_image = detect_combined_homogeneous_area(segmented_image_path)

    if combined_contours:
        pleural_lines = detect_pleural_line(segmented_image_path)
        if pleural_lines:
            for line in pleural_lines:
                x1, y1, x2, y2 = line
                # Check if the pleural line is near the homogeneous area
                for contour in combined_contours:
                    if cv2.pointPolygonTest(np.array(contour, dtype=np.float32), ((x1 + x2) / 2, (y1 + y2) / 2), False) >= 0:
                        print(f"Pneumothorax is suspected in image: {segmented_image_path}")
                        return True

    print(f"No significant pleural lines detected, No Pneumothorax suspected in image: {segmented_image_path}")
    return False

# %%
def iterate_through_images(directory):
    files = os.listdir(directory)
    image_files = [file for file in files if file.endswith('.jpg') or file.endswith('.png')]
    results = []
    for image_file in image_files:
        image_path = os.path.join(directory, image_file)
        result = predict_pneumothorax(image_path)
        results.append(result)
    return results

# Directory containing the segmented lung images
image_directory = '/content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax'

# Get the detection results for all images
detection_results = iterate_through_images(image_directory)
# Out:
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_104.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_113.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_105.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_83.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_96.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_56.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_107.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_87.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_81.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_86.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_60.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_90.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_76.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_43.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_95.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_77.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_109.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_94.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_111.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_103.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_114.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_62.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_85.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_97.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_64.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_74.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_112.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_75.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_92.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_79.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_58.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_99.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_73.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_78.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_108.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_68.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_98.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_80.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_50.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_101.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_88.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_82.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_93.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_110.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_70.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_189.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_2.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_7.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_61.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_25.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_72.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_192.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_38.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_42.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_32.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_188.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_33.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_17.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_30.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_41.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_8.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_52.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_196.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_34.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_13.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_35.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_51.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_36.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_19.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_182.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_55.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_168.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_63.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_15.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_23.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_171.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_195.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_10.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_186.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_66.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_5.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_53.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_102.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_12.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_46.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_31.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_18.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_45.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_71.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_28.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_193.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_14.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_166.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_20.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_197.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_144.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_198.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_142.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_89.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_29.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_24.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_181.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_187.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_16.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_21.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_54.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_39.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_177.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_40.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_37.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_22.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_47.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_49.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_11.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_6.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_185.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_27.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_199.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_173.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_44.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_154.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_153.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_89.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_159.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_162.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_156.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_128.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_96.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_138.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_108.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_176.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_174.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_150.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_169.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_180.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_102.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_90.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_83.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_98.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_140.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_160.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_126.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_143.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_79.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_155.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_136.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_124.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_129.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_101.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_127.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_184.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_88.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_135.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_191.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_130.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_119.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_178.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_146.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_164.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_170.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_151.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_103.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_141.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_116.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_104.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_114.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_99.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_165.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_139.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_134.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_111.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_94.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_133.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_137.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_105.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_148.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_147.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_95.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_152.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_112.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_121.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_132.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_163.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_109.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_145.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_107.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_158.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_190.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_74.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_175.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_110.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_81.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_120.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_131.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_113.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_39.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_33.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_61.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_85.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_23.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_93.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_64.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_199.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_118.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_18.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_6.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_75.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_192.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_80.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_70.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_58.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_71.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_28.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_193.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_56.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_97.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_30.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_31.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_24.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_86.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_11.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_72.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_54.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_34.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_20.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_2.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_43.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_29.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_5.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_44.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_76.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_47.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_42.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_78.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_40.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_32.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_66.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_41.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_45.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_46.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_60.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_117.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_25.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_13.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_55.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_53.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_7.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_38.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_115.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_17.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_122.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_87.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_82.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_19.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_49.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_35.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_27.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_22.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_92.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_62.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_37.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_52.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_73.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_77.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_21.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_63.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_196.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_36.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_68.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_51.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_195.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_50.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_154.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_124.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_187.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_129.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_174.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_119.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_158.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_171.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_128.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_117.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_15.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_118.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_116.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_145.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_150.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_152.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_155.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_180.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_137.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_162.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_126.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_176.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_159.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_130.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_121.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_138.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_131.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_10.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_188.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_146.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_185.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_181.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_14.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_12.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_178.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_115.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_168.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_186.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_16.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_169.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_136.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_141.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_182.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_177.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/Copy of segmented_8.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_132.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_166.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_148.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_160.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_197.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_191.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_170.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_153.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_165.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_139.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_189.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_175.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_135.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_163.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_122.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_190.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_134.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_140.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_156.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_142.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_144.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_173.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_133.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_127.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_184.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_198.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_164.png
# No significant pleural lines detected, No Pneumothorax suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_143.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_151.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_147.png
# Pneumothorax is suspected in image: /content/drive/MyDrive/FYP/Lung/Segmented Images/Pneumothorax/segmented_120.png

# %%
# Calculate accuracy
TP = sum(detection_results)  # Number of True Positives
all_images = len(detection_results)  # Total number of images

accuracy = TP / all_images if all_images > 0 else 0
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.5977011494252874
